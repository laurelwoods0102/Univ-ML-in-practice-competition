# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.load("results/3.1/test_output/0.npy")
a.shape
# Out:
# (3, 512, 512)

# %%
a = a.swapaxes(0, 2)
a.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(a)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
